# %%
print(f"안녕하세요")
print(f"2번입니다.")
# Out:
# 안녕하세요
# 2번입니다.

# %% [markdown]
# # 프로그램 예재. print는 출력기능을 *제공합니다.* 마크다운으로 표시가능

# %%
a = 5
print(f"{a}")
print(f"{a+1}")
# Out:
# 5
# 6

# %%
age = 24
name = "정한준"
height = 172.5
is_student = True
favorite_movie = """
F1
플래쉬
"""
print(f"안녕하십니까 {name}입니다. 나이는 {age}살입니다. 키는 {height}cm입니다. ")
if is_student==True:
    print(f"학생입니다.")
else:
    print(f"학생은 아닙니다.")
print(f"좋아하는 영화는 {favorite_movie}입니다.")
# Out:
# 안녕하십니까 정한준입니다. 나이는 24살입니다. 키는 172.5cm입니다.
# 학생입니다.
# 좋아하는 영화는
# F1
# 플래쉬
# 입니다.

# %%
korean_score = int(input("국어 점수를 입력해주세요 : "))
english_score = int(input("영어 점수를 입력해주세요 : "))
math_score = int(input("수학 점수를 입력해주세요 : "))

sum_score = int(korean_score + english_score + math_score)

average_score = int(sum_score/3)

print(f"총점은 {sum_score}점, 평균은 {average_score}점 입니다.")
# Out:
# 총점은 172점, 평균은 57점 입니다.

# %%
print(f"""안녕하세요
저는 정한준입니다.
이것은 여러줄 문자열 테스트입니다.""")
# Out:
# 안녕하세요
# 저는 정한준입니다.
# 이것은 여러줄 문자열 테스트입니다.

# %%
age = int(input("나이를 입력해주세요 : "))
if age >= 18:
    print(f"성인입니다.")
elif 18 > age >= 13:
    print(f"청소년입니다.")
elif 13 > age >= 0:
    print(f"유아입니다.")
elif 0 >= age:
    print(f"유효하지 않은 나이입니다.")

else:print(f"유효하지 않은 나이입니다.")
# Out:
# 청소년입니다.

# %%
# 다양한 타입 확인하기
age = 20
height = 175.5
name = "김영희"
is_student = True

print(type(age))         # <class 'int'>
print(type(height))      # <class 'float'>
print(type(name))        # <class 'str'>
print(type(is_student))  # <class 'bool'>
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
import math

num1 = 7.5
num2 = 3

print(f"{math.ceil(num1+num2)}")
# Out:
# 11

# %%
# 쇼핑몰 가격 계산 프로그램
print("=== 온라인 쇼핑 계산기 ===")

# 사용자 입력 (input()은 항상 문자열 반환)
product_name = input("상품명을 입력하세요: ")
price_input = input("상품 가격을 입력하세요: ")
quantity_input = input("구매 수량을 입력하세요: ")
discount_input = input("할인율을 입력하세요: ")

# 문자열을 숫자로 변환
price = int(price_input)
quantity = int(quantity_input)
discount = int(discount_input)


# 총 금액 계산
total_price = price * quantity

#할인율 계산
final_price = int(total_price - (total_price*discount/100))

# 결과 출력
print("\n=== 구매 내역 ===")
print(f"상품명: {product_name}")
print(f"단가: {price:,}원")
print(f"수량: {quantity}개")
print(f"총 금액: {total_price:,}원")
print(f"할인율: {discount}%")
print(f"할인 적용 금액: {final_price:,}원")
# Out:
# === 온라인 쇼핑 계산기 ===
#
# === 구매 내역 ===
# 상품명: 123
# 단가: 10,000원
# 수량: 5개
# 총 금액: 50,000원
# 할인율: 10%
# 할인 적용 금액: 45,000원

# %%
score = 0
print(f"{score}")
# Out:
# 0

# %%
# 일반 나눗셈 (실수 결과)
result1 = 10 / 3
print(result1)  # 3.3333333333333335

# 정수 나눗셈 (몫만 반환)
result2 = 10 // 3
print(result2)  # 3

# 나머지 연산
result3 = 10 % 3
print(result3)  # 1
# Out:
# 3.3333333333333335
# 3
# 1
