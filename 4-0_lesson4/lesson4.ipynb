# %%
# 여러 줄 문자열
poem = """
동해물과 백두산이 마르고 닳도록
하느님이 보우하사 우리나라 만세
무궁화 삼천리 화려강산
대한 사람 대한으로 길이 보전하세
"""

print(poem)

# 코드 내 긴 설명문
description = '''
이 프로그램은 학생 성적을 관리하는 시스템입니다.
기능: 성적 입력, 평균 계산, 등급 산출
개발자: 홍길동
버전: 1.0
'''

#doc string이라고 함 여러줄 문자열
# Out:
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세
# 무궁화 삼천리 화려강산
# 대한 사람 대한으로 길이 보전하세

# %%
# 주요 이스케이프 문자
print("첫 번째 줄\n두 번째 줄")  # \n: 줄바꿈
print("탭\t간격\t조정")  # \t: 탭
print("큰따옴표 출력: \"Hello\"")  # \": 큰따옴표
print("작은따옴표 출력: \'Hi\'")  # \': 작은따옴표
print("백슬래시 출력: \\")  # \\: 백슬래시
# Out:
# 첫 번째 줄
# 두 번째 줄
# 탭	간격	조정
# 큰따옴표 출력: "Hello"
# 작은따옴표 출력: 'Hi'
# 백슬래시 출력: \

# %%
x = "제품명\t가격\t제조사"
print(f"{x}\n영이공\n정한준")
print(f"외쳤다. \"좋은아침. 힘세고 굳쎈아침.\" ")
print(f'외쳤다. "좋은아침. 힘세고 굳쎈아침." ')
# Out:
# 제품명	가격	제조사
# 영이공
# 정한준
# 외쳤다. "좋은아침. 힘세고 굳쎈아침."
# 외쳤다. "좋은아침. 힘세고 굳쎈아침."

# %%
# 문자열 인덱싱
word = "Python"

# 양수 인덱스 (앞에서부터)
print(word[0])  # P (첫 번째 문자)
print(word[1])  # y
print(word[2])  # t
print(word[5])  # n (마지막 문자)

# 음수 인덱스 (뒤에서부터)
print(word[-1])  # n (마지막 문자)
print(word[-2])  # o (뒤에서 두 번째)
print(word[-6])  # P (첫 번째 문자)
# Out:
# P
# y
# t
# n
# n
# o
# P

# %%
# 주민등록번호 정보 추출
print("=== 주민등록번호 분석기 ===")

# 주민등록번호 입력 (예: 990101-1234567)
resident_id = input("주민등록번호를 입력하세요 (예: 990101-1234567): ")

# 정보 추출 (슬라이싱 사용)
year = resident_id[0:2]  # 년도 (앞 2자리)
month = resident_id[2:4]  # 월
day = resident_id[4:6]  # 일
gender_code = resident_id[7]  # 성별 코드 (7번째 문자)

# 결과 출력
print(f"\n생년월일: {year}년 {month}월 {day}일")
print(f"성별 코드: {gender_code} (1,3: 남성 / 2,4: 여성)")
print(f"뒷자리: {resident_id[7:]}")
# Out:
# === 주민등록번호 분석기 ===
#
# 생년월일: 03년 10월 31일
# 성별 코드: 5 (1,3: 남성 / 2,4: 여성)
# 뒷자리: 5555555

# %%
# 문자열 슬라이싱
text = "Hello, Python!"

# 기본 슬라이싱
print(text[0:5])    # Hello (인덱스 0부터 4까지)
print(text[7:13])   # Python (인덱스 7부터 12까지)

# 시작 또는 끝 생략
print(text[:5])     # Hello (처음부터 4까지)
print(text[7:])     # Python! (7부터 끝까지)
print(text[:])      # Hello, Python! (전체)

# 음수 인덱스 사용
print(text[-7:])    # Python! (뒤에서 7번째부터 끝까지)
print(text[:-1])    # Hello, Python (마지막 문자 제외)

# 간격 지정
print(text[::2])    # Hlo yhn (2칸씩 건너뛰기)
print(text[::-1])   # !nohtyP ,olleH (역순)
# Out:
# Hello
# Python
# Hello
# Python!
# Hello, Python!
# Python!
# Hello, Python
# Hlo yhn
# !nohtyP ,olleH

# %%
x = "대구시 남구 대명동"
print(f"{x[4:6]}")
print(f"{x[7:]}")
# Out:
# 남구
# 대명동

# %%
x = input("회문 판정입니다. 문장을 입력해주세요 : ")
y = x[::-1]
if x == y :
    print(f"{x}는 회문입니다.")
else:
    print(f"{x}는 회문이 아닙니다.")
# Out:
# 토마토는 회문입니다.

# %%
# 이메일 주소 분석 프로그램
print("=== 이메일 주소 분석기 ===")

email = input("이메일 주소를 입력하세요: ")

# @ 기호의 위치 찾기
at_position = email.find('@')

# 아이디와 도메인 분리
user_id = email[:at_position]
domain = email[at_position + 1:]

# 도메인에서 최상위 도메인 추출
dot_position = domain.rfind('.')  # 마지막 점의 위치
top_level_domain = domain[dot_position + 1:]

# 결과 출력
print(f"\n전체 이메일: {email}")
print(f"아이디: {user_id}")
print(f"도메인: {domain}")
print(f"최상위 도메인: {top_level_domain}")
print(f"이메일 길이: {len(email)}자")
# Out:
# === 이메일 주소 분석기 ===
#
# 전체 이메일: jhjjhs10049@naver.com
# 아이디: jhjjhs10049
# 도메인: naver.com
# 최상위 도메인: com
# 이메일 길이: 21자

# %%
my_mail = "jhjjhs10049@naver.com"
a_position = my_mail.find("@")
my_id = my_mail[:a_position]
my_domain = my_mail[a_position+1:]
high_dot_position = my_mail.rfind(".")
my_high_domain = my_mail[high_dot_position+1:]
my_mail_length = len(my_mail)
print(f"이메일 주소 분석기\n")
print(f"아이디 : {my_id}")
print(f"도매인 : {my_domain}")
print(f"최상위 도매인 : {my_high_domain}")
print(f"이메일 길이 : {my_mail_length}")
# Out:
# 이메일 주소 분석기
#
# 아이디 : jhjjhs10049
# 도매인 : naver.com
# 최상위 도매인 : com
# 이메일 길이 : 21

# %%
product_name = "아메리카노-2000-레귤러"
print(f"{product_name.find("-")}")
print(f"{product_name.rfind("-")}")
print(f"{product_name[product_name.find("-")+1:product_name.rfind("-")]}")
# Out:
# 5
# 10
# 2000

# %%
text = "Hello, Python!"

# 대소문자 변환
print(text.upper())      # HELLO, PYTHON! (모두 대문자)
print(text.lower())      # hello, python! (모두 소문자)
print(text.capitalize()) # Hello, python! (첫 글자만 대문자)
print(text.title())      # Hello, Python! (각 단어 첫 글자 대문자)
print(text.swapcase())   # hELLO, pYTHON! (대소문자 반전)
# Out:
# HELLO, PYTHON!
# hello, python!
# Hello, python!
# Hello, Python!
# hELLO, pYTHON!

# %%
message = "Python is awesome"

# 검색
print(message.find('is'))      # 7 (찾은 위치의 인덱스)
print(message.find('Java'))    # -1 (못 찾으면 -1)
print(message.count('o'))      # 2 ('o'가 나타난 횟수)

# 확인
print(message.startswith('Python'))  # True (시작 확인)
print(message.endswith('some'))      # True (끝 확인)
print('awesome' in message)          # True (포함 확인)
# Out:
# 7
# -1
# 2
# True
# True
# True

# %%
text = "   Hello, World!   "

print(text.strip())   # "Hello, World!" (양쪽 공백 제거)
print(text.lstrip())  # "Hello, World!   " (왼쪽 공백 제거)
print(text.rstrip())  # "   Hello, World!" (오른쪽 공백 제거)

# 특정 문자 제거
url = "https://www.example.com/"
print(url.strip('https://'))  # www.example.com/
# Out:
# Hello, World!
# Hello, World!
#    Hello, World!
# www.example.com

# %%
# split - 문자열을 리스트로 분리
sentence = "Python is easy to learn"
words = sentence.split()  # 공백 기준으로 분리
print(words)  # ['Python', 'is', 'easy', 'to', 'learn']

date = "2024-03-15"
parts = date.split('-')  # '-' 기준으로 분리
print(parts)  # ['2024', '03', '15']

# join - 리스트를 문자열로 결합
fruits = ['apple', 'banana', 'orange']
result = ', '.join(fruits)
print(result)  # apple, banana, orange

# 경로 만들기
path_parts = ['users', 'documents', 'python']
path = '/'.join(path_parts)
print(path)  # users/documents/python

# %%
x = "박남수 박상현 인승호 유병현"
result = x.split()
print(f"{result[0]}")
# Out:
# 박남수

# %%
student_info = []
department = input("학과명을 입력하세요 : ")
student_num = input("학번을 입력하세요 : ")
student_name = input("이름을 입력하세요 : ")
student_info = [department,student_num,student_name]
print(f"{student_info}")
result = " ".join(student_info)
print(f"{result}")
# Out:
# ['학과명', '학번', '이름']
# 학과명 학번 이름

# %%
message = "Hello, Java! Java is great!"

# replace - 문자열 치환
new_message = message.replace('Java', 'Python')
print(new_message)  # Hello, Python! Python is great!

# 치환 횟수 제한
new_message = message.replace('Java', 'Python', 1)  # 첫 번째만 치환
print(new_message)  # Hello, Python! Java is great!
# Out:
# Hello, Python! Python is great!
# Hello, Python! Java is great!

# %%
# 이름 카드 출력 프로그램
print("=== 이름 카드 생성기 ===")

# 정보 입력
name = input("이름: ")
company = input("회사명: ")
position = input("직책: ")
phone = input("전화번호: ")
email = input("이메일: ")

# 카드 너비 설정
width = 40
line = "=" * width

# 이름 카드 출력
print("\n" + line)
print(name.upper().center(width))  # 이름을 대문자로 중앙 정렬
print(position.center(width))  # 직책 중앙 정렬
print(line)
print(f"회사: {company}")
print(f"전화: {phone}")
print(f"이메일: {email}")
print(line)

# 추가 정보
print(f"\n이름 길이: {len(name)}자")
print(f"이메일 도메인: {email.split('@')[1]}")
print(f"이니셜: {name[0].upper()}")
# Out:
# === 이름 카드 생성기 ===
#
# ========================================
#                   정한준
#                    사원
# ========================================
# 회사: 코러싱
# 전화: 01067411589
# 이메일: jhjjhs10049@naver.com
# ========================================
#
# 이름 길이: 3자
# 이메일 도메인: naver.com
# 이니셜: 정

# %%
product_name = "자바칩푸라푸치노"
product_cost = 5000
product_sum = 5

print(f"메뉴명이 {product_name}인 {product_cost}원 {product_sum}잔은 총 {product_cost * product_sum}원 입니다. ")
# Out:
# 메뉴명이 자바칩푸라푸치노인 5000원 5잔은 총 25000원 입니다.

# %%
width = 10
height = 5

print(f"가로가 {width}m이고, 세로가 {height}m인 사각형의 넓이는 {width*height}m^2입니다.")
# Out:
# 가로가 10m이고, 세로가 5m인 사각형의 넓이는 50m^2입니다.

# %%
time = int(input("근무시간 : "))
money = int(input("시급 : "))
tax_per = int(input("세율(%) : "))
money_sum = int(time*money)
tax_sum = int(money_sum*tax_per/100)
end_money = int(money_sum - tax_sum)

print(f"시급 {money}원으로 {time}시간 근무하면 세금{tax_sum}원을 빼고 {end_money}원을 받습니다.")
# Out:
# 시급 100000원으로 5시간 근무하면 세금25000원을 빼고 475000원을 받습니다.

# %%
# 소수점 자릿수 지정
pi = 3.14159265359
print(f"파이: {pi:.2f}")      # 3.14 (소수점 2자리)
print(f"파이: {pi:.4f}")      # 3.1416 (소수점 4자리)

# 천 단위 구분자
price = 1234567
print(f"가격: {price:,}원")   # 가격: 1,234,567원

# 정렬 (< 왼쪽, > 오른쪽, ^ 가운데)
name = "Python"
print(f"|{name:<10}|")  # |Python    |
print(f"|{name:>10}|")  # |    Python|
print(f"|{name:^10}|")  # |  Python  |

# 0으로 채우기
number = 42
print(f"{number:05}")   # 00042 (5자리, 빈 곳을 0으로 채움)

# 여러 옵션 조합
money = 1234567.89
print(f"금액: {money:>15,.2f}원")  # 금액:    1,234,567.89원

# %%
# format() 메서드 사용
name = "김영희"
age = 22

message = "이름: {}, 나이: {}세".format(name, age)
print(message)

# 인덱스 지정
message = "이름: {0}, 나이: {1}세, 다시 이름: {0}".format(name, age)
print(message)

# 키워드 사용
message = "이름: {name}, 나이: {age}세".format(name="이철수", age=30)
print(message)
# Out:
# 이름: 김영희, 나이: 22세
# 이름: 김영희, 나이: 22세, 다시 이름: 김영희
# 이름: 이철수, 나이: 30세

# %%
# 성적표 출력 프로그램
print("=== 성적표 생성기 ===")

# 학생 정보 입력
student_name = input("학생 이름: ")
student_id = input("학번: ")

# 과목별 점수 입력
korean = int(input("국어 점수: "))
english = int(input("영어 점수: "))
math = int(input("수학 점수: "))

# 계산
total = korean + english + math
average = total / 3

# 성적표 출력
print("\n" + "=" * 50)
print(f"{'성적표':^50}")
print("=" * 50)
print(f"이름: {student_name:<10} 학번: {student_id}")
print("-" * 50)
print(f"{'과목':<10} {'점수':>10}")
print("-" * 50)
print(f"{'국어':<10} {korean:>10}점")
print(f"{'영어':<10} {english:>10}점")
print(f"{'수학':<10} {math:>10}점")
print("-" * 50)
print(f"{'총점':<10} {total:>10}점")
print(f"{'평균':<10} {average:>10.2f}점")
print("=" * 50)
# Out:
# === 성적표 생성기 ===
#
# ==================================================
#                        성적표
# ==================================================
# 이름: 정한준        학번: 2605030
# --------------------------------------------------
# 과목                 점수
# --------------------------------------------------
# 국어                100점
# 영어                100점
# 수학                100점
# --------------------------------------------------
# 총점                300점
# 평균             100.00점
# ==================================================

# %%
# 문자열은 변경 불가능
text = "Hello"
# text[0] = 'h'  # 오류 발생! 문자열은 수정할 수 없음

# 새로운 문자열 생성
text = "hello"  # 가능 (새로운 문자열로 대체)
new_text = text.replace('h', 'H')  # 새 문자열 생성
print(new_text)  # Hello
# Out:
# Hello

# %%
# 문자열 정보 분석 프로그램
print("=== 텍스트 분석기 ===")

text = input("분석할 텍스트를 입력하세요: ")

# 기본 정보
total_length = len(text)
without_spaces = text.replace(' ', '')
space_count = total_length - len(without_spaces)

# 특정 문자 개수 세기
a_count = text.lower().count('a')
e_count = text.lower().count('e')
i_count = text.lower().count('i')

# 대소문자 변환
uppercase = text.upper()
lowercase = text.lower()
titlecase = text.title()

# 결과 출력
print("\n" + "=" * 40)
print("텍스트 분석 결과")
print("=" * 40)
print(f"원본 텍스트: {text}")
print(f"전체 길이: {total_length}자")
print(f"공백 제외 길이: {len(without_spaces)}자")
print(f"공백 개수: {space_count}개")
print(f"'a' 개수: {a_count}개")
print(f"'e' 개수: {e_count}개")
print(f"'i' 개수: {i_count}개")
print("-" * 40)
print(f"대문자 변환: {uppercase}")
print(f"소문자 변환: {lowercase}")
print(f"제목 형식: {titlecase}")
print(f"역순: {text[::-1]}")
print("=" * 40)
# Out:
# === 텍스트 분석기 ===
#
# ========================================
# 텍스트 분석 결과
# ========================================
# 원본 텍스트: Brr Brr Pataphim
# 전체 길이: 16자
# 공백 제외 길이: 14자
# 공백 개수: 2개
# 'a' 개수: 2개
# 'e' 개수: 0개
# 'i' 개수: 1개
# ----------------------------------------
# 대문자 변환: BRR BRR PATAPHIM
# 소문자 변환: brr brr pataphim
# 제목 형식: Brr Brr Pataphim
# 역순: mihpataP rrB rrB
# ========================================

# %%
text = "Python Programming Test"
result = text.split()[2][:2].lower()
print(result)
# Out:
# te
