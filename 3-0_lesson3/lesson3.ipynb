# %%
# 정수 나눗셈 또는 몫 (//)
result = 10 // 3
print(result)  # 3 (소수점 이하 버림)

# 나머지 (%)
result = 10 % 3
print(result)  # 1 (10을 3으로 나눈 나머지)

# 거듭제곱 (**)
result = 2 ** 3
print(result)  # 8 (2의 3승)
# Out:
# 3
# 1
# 8

# %%
# 쇼핑몰 할인 계산 프로그램
print("=== 쇼핑몰 할인 계산기 ===")

# 상품 정보 입력
original_price = int(input("원가를 입력하세요: "))
discount_rate = int(input("할인율을 입력하세요 (예: 20): "))

# 할인 금액 계산
discount_amount = original_price * discount_rate / 100

# 최종 가격 계산
final_price = original_price - discount_amount

# 결과 출력
print(f"\n원가: {original_price:,}원")
print(f"할인율: {discount_rate}%")
print(f"할인 금액: {discount_amount:,.0f}원")
print(f"최종 가격: {final_price:,.0f}원")
# Out:
# === 쇼핑몰 할인 계산기 ===
#
# 원가: 5,000원
# 할인율: 10%
# 할인 금액: 500원
# 최종 가격: 4,500원

# %%
# 나이 확인 프로그램
print("=== 나이 확인 시스템 ===")

age = int(input("나이를 입력하세요: "))

# 성인 여부 확인
is_adult = age >= 18

print(f"\n입력하신 나이: {age}세")
print(f"성인 여부: {is_adult}")

# 아직 배우지 않은 조건문이지만    
if is_adult:
    print("성인입니다. 모든 콘텐츠에 접근할 수 있습니다.")
else:
    print("미성년자입니다. 일부 콘텐츠가 제한됩니다.")
# Out:
# === 나이 확인 시스템 ===
#
# 입력하신 나이: 24세
# 성인 여부: True
# 성인입니다. 모든 콘텐츠에 접근할 수 있습니다.

# %%
# 학점 판정 시스템
print("=== 학점 판정 시스템 ===")

# 학생 정보 입력
attendance_rate = int(input("출석률을 입력하세요 (0-100): "))
exam_score = int(input("시험 점수를 입력하세요 (0-100): "))

# 합격 조건: 출석률 80% 이상 AND 시험 점수 60점 이상
passed = attendance_rate >= 80 and exam_score >= 60

# 우수 학생: 출석률 95% 이상 AND 시험 점수 90점 이상
excellent = attendance_rate >= 95 and exam_score >= 90

# 재수강 대상: 출석률 80% 미만 OR 시험 점수 60점 미만
retake = attendance_rate < 80 or exam_score < 60

# 결과 출력
print(f"\n출석률: {attendance_rate}%")
print(f"시험 점수: {exam_score}점")
print(f"합격 여부: {passed}")
print(f"우수 학생: {excellent}")
print(f"재수강 대상: {retake}")

if excellent:
    print("축하합니다! 우수 학생입니다.")
elif passed:
    print("합격입니다.")
else:
    print("재수강이 필요합니다.")
# Out:
# === 학점 판정 시스템 ===
#
# 출석률: 100%
# 시험 점수: 10점
# 합격 여부: False
# 우수 학생: False
# 재수강 대상: True
# 재수강이 필요합니다.

# %%
# 점수 누적 계산
total_score = 0
total_score += 85  # 첫 번째 시험
total_score += 90  # 두 번째 시험
total_score += 88  # 세 번째 시험
print(f"총점: {total_score}")  # 263

# 카운터 증가
count = 0
count += 1  # 1 증가
count += 1  # 1 증가
count += 1  # 1 증가
print(f"카운트: {count}")  # 3
# Out:
# 총점: 263
# 카운트: 3

# %%
# 게임 점수 계산 프로그램
print("=== 게임 점수 시스템 ===")

# 초기값 설정
score = 0
level = 1

# 게임 진행
print("스테이지 1 클리어!")
score += 100
print(f"현재 점수: {score}")

print("\n보너스 아이템 획득!")
score *= 2  # 점수 2배
print(f"현재 점수: {score}")

print("\n스테이지 2 클리어!")
score += 150
print(f"현재 점수: {score}")

# 레벨업 조건 확인 (300점 이상)
if score >= 300:
    level += 1
    print(f"\n레벨업! 현재 레벨: {level}")

print(f"\n최종 점수: {score}")
print(f"최종 레벨: {level}")
# Out:
# === 게임 점수 시스템 ===
# 스테이지 1 클리어!
# 현재 점수: 100
#
# 보너스 아이템 획득!
# 현재 점수: 200
#
# 스테이지 2 클리어!
# 현재 점수: 350
#
# 레벨업! 현재 레벨: 2
#
# 최종 점수: 350
# 최종 레벨: 2

# %%
# 복잡한 계산 - 평균 구하기
korean = 85
english = 90
math = 88

# 잘못된 방법 (우선순위 문제)
average = korean + english + math / 3  # 88/3을 먼저 계산
print(average)  # 204.33333... (잘못된 결과)

# 올바른 방법
average = (korean + english + math) / 3
print(average)  # 87.66666... (올바른 결과)
# Out:
# 204.33333333333334
# 87.66666666666667

# %%
school_name = "영남이공대학교"
my_name = "정한준"

profile = school_name + " " + my_name

print(profile, "1학년")
# Out:
# 영남이공대학교 정한준 1학년

# %%
cola = 2400
count = 2
total = cola * count
print(f"콜라 {count}개의 총 금액은 {total}원 입니다.")
result = "콜라" + str(count) + "개 가격은 " + str(total) + "원 입니다."
print(f"{result}")
# Out:
# 콜라 2개의 총 금액은 4800원 입니다.
# 콜라2개 가격은 4800원 입니다.

# %%
a = 4
b = 5
c = "nice "
print(f"{a * b}{c}")
print(f"{c * b}")
# Out:
# 20nice
# nice nice nice nice nice

# %%
print("=" * 50)
print(f"주문서")
print("=" * 50)
# Out:
# ==================================================
# 주문서
# ==================================================

# %%
# 영수증 출력 프로그램
print("=== 영수증 생성기 ===")

# 상점 정보
store_name = "파이썬 마트"
store_address = "서울시 강남구 파이썬로 123"

# 구매 정보 입력
product_name = input("상품명: ")
unit_price = int(input("단가: "))
quantity = int(input("수량: "))

# 계산
total_price = unit_price * quantity

# 영수증 출력
line = "=" * 40
print("\n" + line)
print(store_name.center(40))  # 중앙 정렬
print(store_address.center(40))
print(line)
print("상품명".ljust(20) + "수량".rjust(10) + "금액".rjust(10))
print(line)
print(product_name.ljust(20) + str(quantity).rjust(10) + f"{unit_price:,}원".rjust(10))
print(line)
print("합계".ljust(30) + f"{total_price:,}원".rjust(10))
print(line)
print("\n감사합니다!".center(40))
print(line)
# Out:
# === 영수증 생성기 ===
#
# ========================================
#                  파이썬 마트
#             서울시 강남구 파이썬로 123
# ========================================
# 상품명                         수량        금액
# ========================================
# 파이썬                          2500,000,000원
# ========================================
# 합계                            1,000,000,000원
# ========================================
#
# 감사합니다!
# ========================================

# %%
# 힌트
hourly_wage = int(input("시급: "))
regular_hours = int(input("일반 근무 시간: "))
night_hours = int(input("야간 근무 시간: "))
vat_per = 8

# 여기에 계산 코드를 작성하세요
# 일반 근무 급여 = 시급 * 일반 근무 시간
# 야간 근무 급여 = 시급 * 1.5 * 야간 근무 시간
# 총 급여 = 일반 근무 급여 + 야간 근무 급여
regular_wage = hourly_wage * regular_hours
night_wage = int(hourly_wage * 1.5 * regular_hours)
sum_wage = regular_wage + night_wage
vat_wage = int(sum_wage*vat_per/100)
after_vat_wage = sum_wage - vat_wage

print("급여 명세서".center(45))
print("=" * 50)
print(f"당신의 기본시급은 {hourly_wage}원 입니다.")
print(f"당신의 일반근무 시간은 {regular_hours}시간 이며, \n일반급여는 {regular_wage}원 입니다.")
print(f"당신의 야간근무 시간은 {night_hours}시간 이며, \n야간수당 1.5배를 하여 야간급여는 {night_wage}원 입니다.")
print(f"이에따른 당신의 총 급여는 {sum_wage}원 입니다.")
print(f"소득세는 {vat_per}%로 총 {vat_wage} 입니다.")
print(f"고로 소득세를 제외한 당신의 총 급여는 {after_vat_wage}")
# Out:
#                     급여 명세서
# ==================================================
# 당신의 기본시급은 5000원 입니다.
# 당신의 일반근무 시간은 5시간 이며,
# 일반급여는 25000원 입니다.
# 당신의 야간근무 시간은 5시간 이며,
# 야간수당 1.5배를 하여 야간급여는 37500원 입니다.
# 이에따른 당신의 총 급여는 62500원 입니다.
# 부가세는 8%로 총 5000 입니다.
# 고로 부가세를 제외한 당신의 총 급여는 57500

# %%
# 4로 나누어떨어지고
# 100으로 나누어떨어지지 않거나
# 400으로 나누어떨어지는 해
  
# 힌트
year = int(input("연도를 입력하세요: "))

# 윤년 조건 확인
is_leap_year = (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0)

print(f"{year}년은 윤년입니까? {is_leap_year}")
# Out:
# 2024년은 윤년입니까? True
